# %% [markdown]
# # Google App store EDA

# %%
# import libraries
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# data import
df = pd.read_csv('./data/googleplaystore.csv')

# %%
# run automatic eda using ydata-profiling library
# import ydata_profiling as yd
# profile = yd.ProfileReport(df)
# profile.to_file(output_file='./pandas_tips_and_tricks/04_ydata_googleplaystore.html')

# %%
# check nthe data 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  int64
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10839 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10841 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10839 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.1+ MB

# %%
# lets have a look at the data
df.head()
# Out:
#                                            App       Category  Rating  \
# 0      Life Made WI-Fi Touchscreen Photo Frame            NaN     1.9
# 1                              Viber Messenger  COMMUNICATION     4.3
# 2                imo free video calls and chat  COMMUNICATION     4.3
# 3        Google Duo - High Quality Video Calls  COMMUNICATION     4.6
# 4  UC Browser - Fast Download Private & Secure  COMMUNICATION     4.5
#
#     Reviews                Size      Installs  Type Price Content Rating  \
# 0        19                3.0M        1,000+   NaN     0       Everyone
# 1  11334799  Varies with device  500,000,000+  Free     0       Everyone
# 2   4785892                 11M  500,000,000+  Free     0       Everyone
# 3   2083237  Varies with device  500,000,000+  Free     0       Everyone
# 4  17712922                 40M  500,000,000+  Free     0           Teen
#
#           Genres       Last Updated               Current Ver  \
# 0            NaN  February 11, 2018                    1.0.19
# 1  Communication      July 18, 2018        Varies with device
# 2  Communication       June 8, 2018          9.8.000000010501
# 3  Communication      July 31, 2018  37.1.206017801.DR37_RC14
# 4  Communication     August 2, 2018               12.8.5.1121
#
#           Android Ver
# 0          4.0 and up
# 1  Varies with device
# 2          4.0 and up
# 3          4.4 and up
# 4          4.0 and up

# %%
# take a samples from big dataset
df.sample(10)
# Out:
#                                   App       Category  Rating  Reviews  \
# 8367    True Contact - Real Caller ID  COMMUNICATION     4.1    32283
# 505         Cameringo+ Filters Camera    PHOTOGRAPHY     4.6    28107
# 6309   Block City Wars + skins export         FAMILY     4.5   762706
# 10058                       AO Player         EVENTS     4.0        9
# 3617       LINE Camera - Photo editor    PHOTOGRAPHY     4.3  1517395
# 4334   DSLR Photography Training apps    PHOTOGRAPHY     4.0      675
# 5669                             Nick  ENTERTAINMENT     4.2   123279
# 9307                       Afterlight    PHOTOGRAPHY     4.3    50893
# 10688  FE Mechanical Engineering Prep         FAMILY     1.0        2
# 8155                       EW Manager       BUSINESS     NaN        0
#
#                      Size      Installs  Type  Price Content Rating  \
# 8367   Varies with device    1,000,000+  Free      0       Everyone
# 505                  5.7M      500,000+  Paid  $2.99       Everyone
# 6309                  28M   10,000,000+  Free      0           Teen
# 10058                3.3M        1,000+  Free      0       Everyone
# 3617   Varies with device  100,000,000+  Free      0       Everyone
# 4334                  15M      100,000+  Free      0       Everyone
# 5669                  25M   10,000,000+  Free      0   Everyone 10+
# 9307                  35M    1,000,000+  Free      0       Everyone
# 10688                 21M        1,000+  Free      0       Everyone
# 8155                 4.4M           10+  Free      0       Everyone
#
#                             Genres       Last Updated         Current Ver  \
# 8367                 Communication      July 26, 2018  Varies with device
# 505                    Photography      June 11, 2018              2.8.26
# 6309                    Simulation     March 30, 2018               6.7.5
# 10058                       Events  December 20, 2017               1.1.4
# 3617                   Photography      March 6, 2018  Varies with device
# 4334                   Photography      July 29, 2017                 2.1
# 5669   Entertainment;Music & Video   January 24, 2018               2.0.8
# 9307                   Photography  November 20, 2014               1.0.6
# 10688                    Education      July 27, 2018           5.33.3669
# 8155                      Business  February 20, 2018               1.0.0
#
#               Android Ver
# 8367   Varies with device
# 505            4.0 and up
# 6309           4.0 and up
# 10058          4.4 and up
# 3617   Varies with device
# 4334           2.3 and up
# 5669           4.4 and up
# 9307         4.0.3 and up
# 10688          5.0 and up
# 8155           4.1 and up

# %%
df.describe()
# Out:
#             Rating       Reviews
# count  9367.000000  1.084100e+04
# mean      4.191513  4.441119e+05
# std       0.515735  2.927629e+06
# min       1.000000  0.000000e+00
# 25%       4.000000  3.800000e+01
# 50%       4.300000  2.094000e+03
# 75%       4.500000  5.476800e+04
# max       5.000000  7.815831e+07

# %%
# to do that lets have a look on uniuqe values

df['Size'].value_counts()
# Out:
# Size
# Varies with device    1695
# 11M                    198
# 12M                    196
# 14M                    194
# 13M                    191
#                       ...
# 173k                     1
# 597k                     1
# 809k                     1
# 411k                     1
# 885k                     1
# Name: count, Length: 461, dtype: int64

# %% [markdown]
# # check that how many Mbs are these in one kb? and how to calculates?
# 1. convert kbs into M
# 2. then remove M from all numbers
# 3. handle `varies with device`.

# %%
df['Size'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # install

# %%
df['Installs'].value_counts()
# Out:
# Installs
# 1,000,000+        1579
# 10,000,000+       1252
# 100,000+          1169
# 10,000+           1054
# 1,000+             908
# 5,000,000+         752
# 100+               719
# 500,000+           539
# 50,000+            479
# 5,000+             477
# 100,000,000+       409
# 10+                386
# 500+               330
# 50,000,000+        289
# 50+                205
# 5+                  82
# 500,000,000+        72
# 1+                  67
# 1,000,000,000+      58
# 0+                  14
# 0                    1
# Name: count, dtype: int64

# %% [markdown]
# # do it as numeric column or group that into different group following binnig method

# %% [markdown]
# # How to handle price

# %%
df['Price'].value_counts()
# Out:
# Price
# 0          10041
# $0.99        148
# $2.99        129
# $1.99         73
# $4.99         72
#            ...
# $3.90          1
# $2.95          1
# $1.97          1
# $1.20          1
# $394.99        1
# Name: count, Length: 92, dtype: int64

# %%
df['Price'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Remove $ sign from all columns using pandas

# %%
df['Type'].value_counts()
# Out:
# Type
# Free    10039
# Paid      800
# Name: count, dtype: int64

# %% [markdown]
# # day 2

# %%
df.head()
# Out:
#                                            App       Category  Rating  \
# 0      Life Made WI-Fi Touchscreen Photo Frame            NaN     1.9
# 1                              Viber Messenger  COMMUNICATION     4.3
# 2                imo free video calls and chat  COMMUNICATION     4.3
# 3        Google Duo - High Quality Video Calls  COMMUNICATION     4.6
# 4  UC Browser - Fast Download Private & Secure  COMMUNICATION     4.5
#
#     Reviews                Size      Installs  Type Price Content Rating  \
# 0        19                3.0M        1,000+   NaN     0       Everyone
# 1  11334799  Varies with device  500,000,000+  Free     0       Everyone
# 2   4785892                 11M  500,000,000+  Free     0       Everyone
# 3   2083237  Varies with device  500,000,000+  Free     0       Everyone
# 4  17712922                 40M  500,000,000+  Free     0           Teen
#
#           Genres       Last Updated               Current Ver  \
# 0            NaN  February 11, 2018                    1.0.19
# 1  Communication      July 18, 2018        Varies with device
# 2  Communication       June 8, 2018          9.8.000000010501
# 3  Communication      July 31, 2018  37.1.206017801.DR37_RC14
# 4  Communication     August 2, 2018               12.8.5.1121
#
#           Android Ver
# 0          4.0 and up
# 1  Varies with device
# 2          4.0 and up
# 3          4.4 and up
# 4          4.0 and up

# %%
df['Size'].value_counts()
# Out:
# Size
# Varies with device    1695
# 11M                    198
# 12M                    196
# 14M                    194
# 13M                    191
#                       ...
# 173k                     1
# 597k                     1
# 809k                     1
# 411k                     1
# 885k                     1
# Name: count, Length: 461, dtype: int64

# %%
df['Size'].unique()
# Out:
# array(['3.0M', 'Varies with device', '11M', '40M', '74M', '62M', '24M',
#        '17M', '61M', '70M', '14M', '5.5M', '4.2M', '25M', '9.4M', '16M',
#        '15M', '2.2M', '21M', '52M', '22M', '2.8M', '6.7M', '19M', '73M',
#        '4.9M', '2.3M', '42M', '3.9M', '20M', '12M', '48M', '23M', '32M',
#        '38M', '31M', '6.2M', '13M', '5.0M', '3.8M', '9.0M', '49M', '27M',
#        '6.1M', '8.1M', '5.1M', '41M', '7.4M', '2.5M', '2.6M', '6.9M',
#        '6.3M', '4.5M', '9.1M', '50M', '8.4M', '30M', '7.1M', '6.4M',
#        '4.0M', '6.5M', '44M', '45M', '55M', '3.3M', '9.9M', '10M', '8.6M',
#        '7.9M', '9.2M', '5.9M', '5.3M', '35M', '2.4M', '1.4M', '76M',
#        '7.5M', '8.9M', '33M', '56M', '80M', '46M', '83M', '93M', '99M',
#        '54M', '9.8M', '37M', '57M', '34M', '97M', '6.0M', '89M', '7.3M',
#        '8.8M', '36M', '18M', '26M', '5.2M', '81M', '39M', '4.6M', '7.2M',
#        '1.1M', '920k', '4.3M', '4.8M', '9.7M', '6.6M', '2.9M', '47M',
#        '94M', '91M', '3.6M', '318k', '79M', '9.3M', '3.7M', '28M', '60M',
#        '29M', '53M', '1.9M', '7.6M', '8.3M', '92M', '1.8M', '7.0M',
#        '1.5M', '266k', '67M', '64M', '4.4M', '5.8M', '8.7M', '51M',
#        '1.6M', '3.4M', '58M', '8.2M', '585k', '5.7M', '69M', '1.3M',
#        '87M', '43M', '50k', '88M', '68M', '96M', '592k', '656k', '72M',
#        '9.5M', '8.5M', '4.7M', '59M', '3.1M', '3.5M', '7.8M', '8.0M',
#        '78M', '1.7M', '72k', '82M', '1.2M', '100M', '857k', '51k', '954k',
#        '2.1M', '1.0M', '887k', '63M', '7.7M', '2.0M', '6.8M', '4.1M',
#        '636k', '754k', '2.7M', '376k', '992k', '75M', '66M', '95M', '77M',
#        '5.6M', '8.5k', '98M', '241k', '5.4M', '71M', '314k', '730k',
#        '756k', '74k', '444k', '306k', '86M', '175k', '647k', '598k',
#        '219k', '9.6M', '116k', '837k', '221k', '309k', '485k', '562k',
#        '48k', '65M', '3.2M', '161k', '10.0M', '29k', '552k', '421k',
#        '683k', '842k', '511k', '913k', '97k', '629k', '85M', '154k',
#        '89k', '1020k', '232k', '41k', '373k', '208k', '862k', '975k',
#        '772k', '196k', '251k', '313k', '58k', '239k', '220k', '965k',
#        '545k', '283k', '90M', '717k', '308k', '335k', '721k', '430k',
#        '200k', '417k', '506k', '437k', '323k', '554k', '499k', '801k',
#        '600k', '228k', '164k', '54k', '18k', '879k', '170k', '160k',
#        '144k', '141k', '143k', '473k', '26k', '470k', '240k', '172k',
#        '688k', '201k', '23k', '84M', '720k', '953k', '746k', '91k',
#        '818k', '61k', '609k', '350k', '70k', '778k', '103k', '209k',
#        '173k', '597k', '809k', '411k', '643k', '20k', '785k', '914k',
#        '903k', '948k', '33k', '387k', '190k', '17k', '192k', '73k',
#        '404k', '364k', '467k', '582k', '293k', '902k', '81k', '475k',
#        '705k', '569k', '840k', '222k', '55k', '516k', '780k', '961k',
#        '642k', '458k', '775k', '500k', '957k', '921k', '874k', '981k',
#        '892k', '970k', '234k', '861k', '157k', '79k', '695k', '624k',
#        '525k', '853k', '551k', '176k', '556k', '526k', '704k', '899k',
#        '375k', '980k', '779k', '930k', '203k', '371k', '78k', '924k',
#        '939k', '45k', '714k', '322k', '976k', '210k', '383k', '454k',
#        '812k', '442k', '412k', '459k', '782k', '429k', '728k', '816k',
#        '414k', '334k', '186k', '25k', '153k', '353k', '122k', '400k',
#        '787k', '986k', '245k', '288k', '811k', '329k', '784k', '626k',
#        '193k', '420k', '226k', '257k', '676k', '169k', '655k', '904k',
#        '243k', '319k', '191k', '514k', '237k', '269k', '940k', '663k',
#        '118k', '518k', '292k', '11k', '696k', '544k', '713k', '865k',
#        '540k', '93k', '872k', '716k', '982k', '351k', '847k', '860k',
#        '253k', '378k', '14k', '317k', '121k', '206k', '478k', '460k',
#        '496k', '613k', '691k', '951k', '963k', '27k', '82k', '743k',
#        '498k', '749k', '881k', '601k', '108k', '34k', '942k', '259k',
#        '28k', '916k', '994k', '608k', '270k', '523k', '280k', '24k',
#        '39k', '246k', '658k', '44k', '67k', '619k', '238k', '549k',
#        '898k', '885k'], dtype=object)

# %%
# Convert sizes in KB to MB
mask_kb = df['Size'].str.contains('k', na=False)
df.loc[mask_kb, 'Size'] = (df.loc[mask_kb, 'Size'].str.replace('k', '').astype(float) / 1024).round(2).astype(str) + 'M'

# Ensure sizes in MB end with 'M'
mask_mb = df['Size'].str.contains('M', na=False)
df.loc[mask_mb, 'Size'] = df.loc[mask_mb, 'Size'].str.replace('M', '').astype(float).round(2).astype(str) + 'M'

# %%
df['Size'].replace('Varies with device', 0, inplace=True)
df.head(20)
# Out:
#                                             App       Category  Rating  \
# 0       Life Made WI-Fi Touchscreen Photo Frame            NaN     1.9
# 1                               Viber Messenger  COMMUNICATION     4.3
# 2                 imo free video calls and chat  COMMUNICATION     4.3
# 3         Google Duo - High Quality Video Calls  COMMUNICATION     4.6
# 4   UC Browser - Fast Download Private & Secure  COMMUNICATION     4.5
# 5                 imo free video calls and chat  COMMUNICATION     4.3
# 6                               Viber Messenger  COMMUNICATION     4.3
# 7                   LINE: Free Calls & Messages  COMMUNICATION     4.2
# 8   UC Browser - Fast Download Private & Secure  COMMUNICATION     4.5
# 9                               Viber Messenger  COMMUNICATION     4.3
# 10                imo free video calls and chat  COMMUNICATION     4.3
# 11                              Viber Messenger  COMMUNICATION     4.3
# 12                  LINE: Free Calls & Messages  COMMUNICATION     4.2
# 13                             Candy Crush Saga           GAME     4.4
# 14                                 Temple Run 2           GAME     4.3
# 15                                          Pou           GAME     4.3
# 16                                          Pou           GAME     4.3
# 17                             Candy Crush Saga           GAME     4.4
# 18                               My Talking Tom           GAME     4.5
# 19                                 Temple Run 2           GAME     4.3
#
#      Reviews   Size      Installs  Type Price Content Rating         Genres  \
# 0         19   3.0M        1,000+   NaN     0       Everyone            NaN
# 1   11334799      0  500,000,000+  Free     0       Everyone  Communication
# 2    4785892  11.0M  500,000,000+  Free     0       Everyone  Communication
# 3    2083237      0  500,000,000+  Free     0       Everyone  Communication
# 4   17712922  40.0M  500,000,000+  Free     0           Teen  Communication
# 5    4785988  11.0M  500,000,000+  Free     0       Everyone  Communication
# 6   11334973      0  500,000,000+  Free     0       Everyone  Communication
# 7   10790289      0  500,000,000+  Free     0       Everyone  Communication
# 8   17714850  40.0M  500,000,000+  Free     0           Teen  Communication
# 9   11334973      0  500,000,000+  Free     0       Everyone  Communication
# 10   4785988  11.0M  500,000,000+  Free     0       Everyone  Communication
# 11  11335255      0  500,000,000+  Free     0       Everyone  Communication
# 12  10790289      0  500,000,000+  Free     0       Everyone  Communication
# 13  22426677  74.0M  500,000,000+  Free     0       Everyone         Casual
# 14   8118609  62.0M  500,000,000+  Free     0       Everyone         Action
# 15  10485308  24.0M  500,000,000+  Free     0       Everyone         Casual
# 16  10485334  24.0M  500,000,000+  Free     0       Everyone         Casual
# 17  22428456  74.0M  500,000,000+  Free     0       Everyone         Casual
# 18  14891223      0  500,000,000+  Free     0       Everyone         Casual
# 19   8118937  62.0M  500,000,000+  Free     0       Everyone         Action
#
#          Last Updated               Current Ver         Android Ver
# 0   February 11, 2018                    1.0.19          4.0 and up
# 1       July 18, 2018        Varies with device  Varies with device
# 2        June 8, 2018          9.8.000000010501          4.0 and up
# 3       July 31, 2018  37.1.206017801.DR37_RC14          4.4 and up
# 4      August 2, 2018               12.8.5.1121          4.0 and up
# 5        June 8, 2018          9.8.000000010501          4.0 and up
# 6       July 18, 2018        Varies with device  Varies with device
# 7       July 26, 2018        Varies with device  Varies with device
# 8      August 2, 2018               12.8.5.1121          4.0 and up
# 9       July 18, 2018        Varies with device  Varies with device
# 10       June 8, 2018          9.8.000000010501          4.0 and up
# 11      July 18, 2018        Varies with device  Varies with device
# 12      July 26, 2018        Varies with device  Varies with device
# 13       July 5, 2018                 1.129.0.2          4.1 and up
# 14       July 5, 2018                    1.49.1          4.0 and up
# 15       May 25, 2018                    1.4.77          4.0 and up
# 16       May 25, 2018                    1.4.77          4.0 and up
# 17       July 5, 2018                 1.129.0.2          4.1 and up
# 18      July 19, 2018                 4.8.0.132          4.1 and up
# 19       July 5, 2018                    1.49.1          4.0 and up

# %%
df['Size'].value_counts()
# Out:
# Size
# 0        1695
# 11.0M     198
# 12.0M     196
# 14.0M     194
# 13.0M     191
#          ...
# 0.55M       1
# 0.75M       1
# 0.56M       1
# 0.78M       1
# 0.27M       1
# Name: count, Length: 274, dtype: int64
